# %% [markdown]
# # Visual Storytelling Demo
#
# This notebook demonstrates the visual storytelling capabilities of our advanced computer vision system.

# %%
# Import required libraries
import sys
from pathlib import Path
import torch
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

from src.models import SimpleVisualStorytellingModel, StorytellingConfig
from src.utils import get_device, set_seed
from src.eval import StorytellingEvaluator
